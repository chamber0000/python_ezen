# %%
import pandas as pd

# %%
##파일 로드
uriage = pd.read_csv("../csv/uriage.csv")
uriage.head()
# Out:
#       purchase_date item_name  item_price customer_name
# 0  2019-06-13 18:02       상품A       100.0           김가온
# 1  2019-07-13 13:05     상 품 S         NaN           김우찬
# 2  2019-05-11 19:42     상 품 a         NaN           김유찬
# 3  2019-02-12 23:40       상품Z      2600.0           김재현
# 4   2019-04-22 3:09       상품a         NaN           김강현

# %%
uriage['purchase_date'] = uriage['purchase_date'].replace(" ","")

# %%
## 결측치 확인
uriage.isna().sum()
# Out:
# purchase_date      0
# item_name          0
# item_price       387
# customer_name      0
# dtype: int64

# %%
## 결측치 확인
uriage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2999 entries, 0 to 2998
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   purchase_date  2999 non-null   object
#  1   item_name      2999 non-null   object
#  2   item_price     2612 non-null   float64
#  3   customer_name  2999 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 93.8+ KB

# %% [markdown]
# 1. purchase_data컬럼의 데이터 타입을 시계열 데이터로 변경
# 2. item_name의 데이터를 모두 대문자로 변경
# 3. item_name의 데이터에서 공백을 삭제
# 4. itme_name을 기준으로 오름차순 정렬
# 5. 인덱스를 초기화(기존의 인덱스는 삭제)

# %%
## 1. 시계열 데이터로 변경
## pd.to_datatime(변경할 데이터, format= '데이터의 형태')
uriage['purchase_date'] = pd.to_datetime(uriage['purchase_date'], format= '%Y-%m-%d %H:%M')

# %%
## 2. item_name 컬럼의 데이터를 대문자로 변경
# case 1 문자를 대문자로
uriage['item_name'].str.upper()

# case 2 
# apply() : 시리즈 형태의 데이터를 항목 하나하나씩 함수에 대입하여 출력값을 시리즈 형태로 변경하여 출력
# 일반 함수 생성
def change(x):
    return x.upper()

uriage['item_name'].apply(change)

# case 3
## apply(lambda함수)
uriage['item_name'].apply(lambda x : x.upper())
# Out:
# 0         상품A
# 1       상 품 S
# 2       상 품 A
# 3         상품Z
# 4         상품A
#         ...
# 2994      상품Y
# 2995      상품M
# 2996      상품Q
# 2997      상품H
# 2998      상품D
# Name: item_name, Length: 2999, dtype: object

# %%
## 공백 제거
## 문자열 사이의 공백도 삭제해야되기 때문에 replace(" ","")

# case 1
uriage['item_name'].str.replace(" ","")

## case 2
def change(x):
    return x.replace(" ","")

uriage['item_name'].apply(change)

# case 3
## apply(lambda함수)
uriage['item_name'].apply(lambda x : x.replace(" ",""))
# Out:
# 0       상품A
# 1       상품S
# 2       상품a
# 3       상품Z
# 4       상품a
#        ...
# 2994    상품Y
# 2995    상품M
# 2996    상품Q
# 2997    상품H
# 2998    상품D
# Name: item_name, Length: 2999, dtype: object

# %%
## 대문자 변경 및 공백 제거
#case1
uriage['item_name'].str.upper().str.replace(" ","")
#case2
def change(x):
    # return x.upper().replace(" ","")
    y = x.upper()
    return y.replace(" ","")

uriage['item_name'].apply(change)
#case3
uriage['item_name'] = uriage['item_name'].apply(lambda x : x.upper().replace(" ",""))
uriage['item_name']
# Out:
# 0       상품A
# 1       상품S
# 2       상품A
# 3       상품Z
# 4       상품A
#        ...
# 2994    상품Y
# 2995    상품M
# 2996    상품Q
# 2997    상품H
# 2998    상품D
# Name: item_name, Length: 2999, dtype: object

# %%
# item name 기준으로 오름차순 정렬
uriage.sort_values('item_name', inplace=True)

# %%
# index 초기화 (기존의 인덱스는 삭제)
uriage.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 결측치에 데이타를 치환
# 1. 상품 A의 item_price의 값은 결측치 중 상품A이면 상품 A의 평균 값을 치환
# 2. 나머지 상품들도 같은 방법으로 치환

# %%
## item_name이 상품A의 경우만 추출
fig = uriage['item_name'] == '상품A'

# %%
uriage.loc[fig]
# Out:
#           purchase_date item_name  item_price customer_name
# 0   2019-06-13 18:02:00       상품A       100.0           김가온
# 1   2019-05-19 20:22:00       상품A       100.0           김시훈
# 2   2019-06-25 08:13:00       상품A       100.0           김유진
# 3   2019-06-13 16:03:00       상품A       100.0           김건희
# 4   2019-02-10 00:28:00       상품A       100.0           김하랑
# ..                  ...       ...         ...           ...
# 134 2019-01-13 11:50:00       상품A       100.0           김시율
# 135 2019-03-09 14:20:00       상품A         NaN           김우찬
# 136 2019-05-11 19:42:00       상품A         NaN           김유찬
# 137 2019-04-25 17:15:00       상품A       100.0           김강현
# 138 2019-05-20 14:05:00       상품A       100.0           김지안
#
# [139 rows x 4 columns]

# %%
uriage.loc[fig, 'item_price']
# Out:
# 0      100.0
# 1      100.0
# 2      100.0
# 3      100.0
# 4      100.0
#        ...
# 134    100.0
# 135      NaN
# 136      NaN
# 137    100.0
# 138    100.0
# Name: item_price, Length: 139, dtype: float64

# %%
# 상품이 A이고, item_price가 결측치인 경우 True
fig2 = uriage.loc[item_A, 'item_price'].isna()

# %%
uriage.loc[fig].loc[fig2]
# Out:
#           purchase_date item_name  item_price customer_name
# 18  2019-04-11 02:22:00       상품A         NaN           김선우
# 22  2019-07-07 21:49:00       상품A         NaN           김은우
# 32  2019-07-14 03:39:00       상품A         NaN           김시우
# 38  2019-05-25 12:51:00       상품A         NaN           김재민
# 44  2019-02-28 04:11:00       상품A         NaN           김서준
# 46  2019-02-13 07:28:00       상품A         NaN           김시환
# 48  2019-07-31 01:32:00       상품A         NaN           김윤찬
# 51  2019-04-06 11:06:00       상품A         NaN           김태인
# 58  2019-03-15 09:14:00       상품A         NaN           김강현
# 59  2019-06-24 05:06:00       상품A         NaN           김시호
# 68  2019-03-16 17:23:00       상품A         NaN           김주원
# 86  2019-01-15 22:59:00       상품A         NaN           김하진
# 96  2019-01-21 03:33:00       상품A         NaN           김진우
# 102 2019-07-19 14:12:00       상품A         NaN           김서윤
# 110 2019-03-05 20:21:00       상품A         NaN           김주혁
# ...

# %%
## 조건식 2개
fig = uriage['item_name'] == '상품A'
fig2 = uriage['item_price'].isna()

# %%
# 상품A이고 결측치인경우
uriage.loc[fig & fig2]
# Out:
#           purchase_date item_name  item_price customer_name
# 18  2019-04-11 02:22:00       상품A         NaN           김선우
# 22  2019-07-07 21:49:00       상품A         NaN           김은우
# 32  2019-07-14 03:39:00       상품A         NaN           김시우
# 38  2019-05-25 12:51:00       상품A         NaN           김재민
# 44  2019-02-28 04:11:00       상품A         NaN           김서준
# 46  2019-02-13 07:28:00       상품A         NaN           김시환
# 48  2019-07-31 01:32:00       상품A         NaN           김윤찬
# 51  2019-04-06 11:06:00       상품A         NaN           김태인
# 58  2019-03-15 09:14:00       상품A         NaN           김강현
# 59  2019-06-24 05:06:00       상품A         NaN           김시호
# 68  2019-03-16 17:23:00       상품A         NaN           김주원
# 86  2019-01-15 22:59:00       상품A         NaN           김하진
# 96  2019-01-21 03:33:00       상품A         NaN           김진우
# 102 2019-07-19 14:12:00       상품A         NaN           김서윤
# 110 2019-03-05 20:21:00       상품A         NaN           김주혁
# ...

# %%
# 상품A이고 결측치가 아닌경우
uriage.loc[fig & ~fig2]
# Out:
#           purchase_date item_name  item_price customer_name
# 0   2019-06-13 18:02:00       상품A       100.0           김가온
# 1   2019-05-19 20:22:00       상품A       100.0           김시훈
# 2   2019-06-25 08:13:00       상품A       100.0           김유진
# 3   2019-06-13 16:03:00       상품A       100.0           김건희
# 4   2019-02-10 00:28:00       상품A       100.0           김하랑
# ..                  ...       ...         ...           ...
# 131 2019-06-05 02:25:00       상품A       100.0           김현성
# 133 2019-06-24 02:56:00       상품A       100.0           김현진
# 134 2019-01-13 11:50:00       상품A       100.0           김시율
# 137 2019-04-25 17:15:00       상품A       100.0           김강현
# 138 2019-05-20 14:05:00       상품A       100.0           김지안
#
# [117 rows x 4 columns]

# %%
# 상품A이고 결측치가 아닌경우에 item_price의 평균값
a_price = uriage.loc[fig & ~fig2, 'item_price'].mean()
a_price
# Out:
# 100.0

# %%
## 상품이 A이고, item_price가 결측치인 값에 치환.
uriage.loc[fig & fig2].fillna(a_price)
# Out:
#           purchase_date item_name  item_price customer_name
# 18  2019-04-11 02:22:00       상품A       100.0           김선우
# 22  2019-07-07 21:49:00       상품A       100.0           김은우
# 32  2019-07-14 03:39:00       상품A       100.0           김시우
# 38  2019-05-25 12:51:00       상품A       100.0           김재민
# 44  2019-02-28 04:11:00       상품A       100.0           김서준
# 46  2019-02-13 07:28:00       상품A       100.0           김시환
# 48  2019-07-31 01:32:00       상품A       100.0           김윤찬
# 51  2019-04-06 11:06:00       상품A       100.0           김태인
# 58  2019-03-15 09:14:00       상품A       100.0           김강현
# 59  2019-06-24 05:06:00       상품A       100.0           김시호
# 68  2019-03-16 17:23:00       상품A       100.0           김주원
# 86  2019-01-15 22:59:00       상품A       100.0           김하진
# 96  2019-01-21 03:33:00       상품A       100.0           김진우
# 102 2019-07-19 14:12:00       상품A       100.0           김서윤
# 110 2019-03-05 20:21:00       상품A       100.0           김주혁
# ...

# %%
uriage.value_counts('item_name')
# Out:
# item_name
# 상품S    140
# 상품A    139
# 상품R    136
# 상품P    135
# 상품V    134
# 상품C    133
# 상품F    126
# 상품D    125
# 상품Q    125
# 상품O    124
# 상품W    121
# 상품N    119
# 상품T    117
# 상품J    116
# 상품X    116
# 상품I    114
# 상품M    113
# 상품B    113
# 상품L    110
# 상품G    110
# 상품K    109
# 상품H    109
# 상품U    107
# 상품E    105
# 상품Y    102
# 상품Z      1
# dtype: int64

# %%
uriage.value_counts('item_name').index
# Out:
# Index(['상품S', '상품A', '상품R', '상품P', '상품V', '상품C', '상품F', '상품D', '상품Q', '상품O',
#        '상품W', '상품N', '상품T', '상품J', '상품X', '상품I', '상품M', '상품B', '상품L', '상품G',
#        '상품K', '상품H', '상품U', '상품E', '상품Y', '상품Z'],
#       dtype='object', name='item_name')

# %%
name_list = uriage['item_name'].unique()
name_list
# Out:
# array(['상품A', '상품B', '상품C', '상품D', '상품E', '상품F', '상품G', '상품H', '상품I',
#        '상품J', '상품K', '상품L', '상품M', '상품N', '상품O', '상품P', '상품Q', '상품R',
#        '상품S', '상품T', '상품U', '상품V', '상품W', '상품X', '상품Y', '상품Z'],
#       dtype=object)

# %%
## 반복문을 이용하여 모든 결측치를 치환
uriage2 = uriage.copy()

# %%
for i in name_list:
    ## 조건식 생성
    fig = uriage['item_name'] == i
    fig2= uriage['item_price'].isna()
    
    ##fig와 ~fig2의 조건식이 모두 참일때의 item_price의 평균 값
    mean_price = uriage.loc[fig & ~fig2, 'item_price'].mean()
    ##fig와 fig2의 조건식이 모두 참일때의 item_price에 mean_price의 값을 대체
    uriage.loc[fig & fig2, 'item_price'] = mean_price

# %%
uriage.isna().sum()
# Out:
# purchase_date    0
# item_name        0
# item_price       0
# customer_name    0
# dtype: int64

# %%
# if 조건문식 내 함수 사용하기
def change(df, x):
    # 조건식 생성
    fig = df['item_name'] == x
    fig2 = df['item_price'].isna()

    ## fig와 ~fig2인 경우, item_price의 평균
    mean_price = df.loc[fig & ~fig2, 'item_price'].mean()

    # 평균값을 결측치에 대체
    df.loc[fig & fig2, 'item_price'] = mean_price

# %%
uriage2.isna().sum()
# Out:
# purchase_date      0
# item_name          0
# item_price       387
# customer_name      0
# dtype: int64

# %%
for i in name_list:
    change(uriage2, i)

# %%
uriage2.isna().sum()
# Out:
# purchase_date    0
# item_name        0
# item_price       0
# customer_name    0
# dtype: int64

# %%
uriage.query("item_name == '상품B'")
# Out:
#           purchase_date item_name  item_price customer_name
# 139 2019-06-07 00:03:00       상품B       200.0           김재희
# 140 2019-03-15 06:06:00       상품B       200.0           김서윤
# 141 2019-06-25 03:12:00       상품B       200.0           김규민
# 142 2019-04-18 16:44:00       상품B       200.0           김유빈
# 143 2019-07-27 09:00:00       상품B       200.0           김현수
# ..                  ...       ...         ...           ...
# 247 2019-02-17 01:46:00       상품B       200.0           김지완
# 248 2019-05-21 11:17:00       상품B       200.0           김태우
# 249 2019-07-02 07:39:00       상품B       200.0           김정민
# 250 2019-07-09 15:27:00       상품B       200.0           김성민
# 251 2019-01-20 19:05:00       상품B       200.0           김준호
#
# [113 rows x 4 columns]
